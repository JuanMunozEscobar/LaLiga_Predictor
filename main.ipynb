# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
pd.set_option('display.max_rows', 10)

# %%
# Load the CSV data into a DataFrame
df = pd.read_csv('LaLigaHistory.csv', index_col= 0)

# Convert the date column to datetime objects for easier date manipulation
df['date_GMT'] = pd.to_datetime(df['date_GMT'], format = ('%b %d %Y - %I:%M%p'))

# %%
# Display the DataFrame and its data types for verification
#print(df.dtypes)

# %%
# Convert categorical text data to numerical codes for model training

df["home_team_code"] = df["home_team_name"].astype("category").cat.codes
df["away_team_code"] = df["away_team_name"].astype("category").cat.codes
df["stadium_code"] = df["stadium_name"].astype("category").cat.codes

# Extract the day of the week from the date to use as a feature

df["day_of_week"] = df["date_GMT"].dt.day_of_week

# Map match results to numerical values: 1 for Win (W), 0 for Loss (L), 2 for Draw (D)

df["target"] = df["Result"].map({"W": 1, "L": 0, "D": 2})

# Display the first few rows to ensure correct mapping and transformations

#df.head()

# %%
train = df[df["date_GMT"] < '2023-08-05']
test = df[(df["date_GMT"] >= '2023-08-05') & (df["date_GMT"] < '2024-04-01')]

# Initialize the RandomForestClassifier with specified hyperparameters
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state= 1)

# Define the predictor variables/features to use for training the model
predictor = ["home_team_code","away_team_code", "stadium_code", 
             "day_of_week","Game Week","time"]

rf.fit(train[predictor], train["target"])
preds = rf.predict(test[predictor])
error = accuracy_score(test["target"], preds)

# %%
# Create a DataFrame to compare actual vs predicted results
combined = pd.DataFrame(dict(actual=test["target"], predicted = preds))

# Display a crosstabulation of actual vs predicted results for better analysis
pd.crosstab(index = combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0   1   2
# actual
# 0          25  40  12
# 1          11  97  25
# 2          18  61   9

# %%
grouped_home_team_df = df.groupby("home_team_name")
group_home = grouped_home_team_df.get_group("Real Madrid")

# %%
def rolling_avg(group_home, cols, new_cols):
    group_home = group_home.sort_values("date_GMT")
    rolling_stats_home = group_home[cols].rolling(20, closed='left').mean()
    group_home[new_cols] = rolling_stats_home
    group_home = group_home.dropna(subset=new_cols)
    return group_home

# %%
cols = ["home_team_goal_count", 
        "home_team_shots",
        "home_team_shots_on_target", ]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_avg(group_home, cols, new_cols)
# Out:
#                       date_GMT      status  attendance home_team_name  \
# timestamp
# 1602952200 2020-10-17 16:30:00    complete         NaN    Real Madrid
# 1604149200 2020-10-31 13:00:00    complete         0.0    Real Madrid
# 1606593600 2020-11-28 20:00:00    complete         0.0    Real Madrid
# 1607803200 2020-12-12 20:00:00    complete         0.0    Real Madrid
# 1608066000 2020-12-15 21:00:00    complete         0.0    Real Madrid
# ...                        ...         ...         ...            ...
# 1743890400 2025-04-05 22:00:00  incomplete         NaN    Real Madrid
# 1745100000 2025-04-19 22:00:00  incomplete         NaN    Real Madrid
# 1746309600 2025-05-03 22:00:00  incomplete         NaN    Real Madrid
# 1747173600 2025-05-13 22:00:00  incomplete         NaN    Real Madrid
# 1748124000 2025-05-24 22:00:00  incomplete         NaN    Real Madrid
#
#                   away_team_name                     referee  Game Week  \
# timestamp
# 1602952200                 Cadiz        Santiago Jaime Latre          6
# 1604149200             SD Huesca      Pablo González Fuertes          8
# 1606593600      Deportivo Alavés         Adrián Cordero Vega         11
# 1607803200       Atletico Madrid  Antonio Miguel Mateu Lahoz         13
# 1608066000  Athletic Club Bilbao           Jesús Gil Manzano         19
# ...                          ...                         ...        ...
# 1743890400           Valencia CF                         NaN         30
# 1745100000  Athletic Club Bilbao                         NaN         32
# 1746309600         Celta de Vigo                         NaN         34
# 1747173600          RCD Mallorca                         NaN         36
# 1748124000         Real Sociedad                         NaN         38
#
#             Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_ppg  ...  Result  \
# timestamp                                                         ...
# 1602952200                   3.0                  3.00      2.21  ...       L
# 1604149200                   1.5                  0.75      2.21  ...       W
# 1606593600                   2.0                  1.00      2.21  ...       L
# 1607803200                   1.5                  2.50      2.21  ...       W
# 1608066000                   1.8                  0.71      2.21  ...       W
# ...                          ...                   ...       ...  ...     ...
# 1743890400                   0.0                  0.00      0.00  ...       D
# 1745100000                   0.0                  0.00      0.00  ...       D
# 1746309600                   0.0                  0.00      0.00  ...       D
# 1747173600                   0.0                  0.00      0.00  ...       D
# 1748124000                   0.0                  0.00      0.00  ...       D
#
#             time  home_team_code  away_team_code  stadium_code  day_of_week  \
# timestamp
# 1602952200    16              19               5             7            5
# 1604149200    13              19              23             7            5
# 1606593600    20              19               7             7            5
# 1607803200    20              19               2             7            5
# 1608066000    21              19               1             7            1
# ...          ...             ...             ...           ...          ...
# 1743890400    22              19              26            21            5
# 1745100000    22              19               1            21            5
# 1746309600    22              19               6            21            5
# 1747173600    22              19              16            21            1
# 1748124000    22              19              20            21            5
#
#             target home_team_goal_count_rolling home_team_shots_rolling  \
# timestamp
# 1602952200       0                         1.65                   14.35
# 1604149200       1                         1.55                   14.60
# 1606593600       0                         1.55                   14.55
# 1607803200       1                         1.55                   14.75
# 1608066000       1                         1.65                   14.60
# ...            ...                          ...                     ...
# 1743890400       2                         0.85                    3.80
# 1745100000       2                         0.65                    2.65
# 1746309600       2                         0.55                    2.20
# 1747173600       2                         0.40                    1.50
# 1748124000       2                         0.25                    0.65
#
#             home_team_shots_on_target_rolling
# timestamp
# 1602952200                               7.30
# 1604149200                               7.20
# 1606593600                               7.10
# 1607803200                               7.05
# 1608066000                               6.85
# ...                                       ...
# 1743890400                               2.15
# 1745100000                               1.40
# 1746309600                               1.10
# 1747173600                               0.60
# 1748124000                               0.00
#
# [94 rows x 59 columns]

# %%
df_rolling = df.groupby("home_team_name").apply(lambda x: rolling_avg(x,cols,new_cols))
#df_rolling
# Out:
# C:\Users\munoz\AppData\Local\Temp\ipykernel_15540\1900319699.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling = df.groupby("home_team_name").apply(lambda x: rolling_avg(x,cols,new_cols))

# %%
df_rolling.droplevel("home_team_name")
# Out:
#                       date_GMT      status  attendance home_team_name  \
# timestamp
# 1692466200 2023-08-19 17:30:00    complete         NaN        Almería
# 1693598400 2023-09-01 20:00:00    complete         NaN        Almería
# 1695495600 2023-09-23 19:00:00    complete         NaN        Almería
# 1696161600 2023-10-01 12:00:00    complete         NaN        Almería
# 1698494400 2023-10-28 12:00:00    complete         NaN        Almería
# ...                        ...         ...         ...            ...
# 1743890400 2025-04-05 22:00:00  incomplete         NaN     Villarreal
# 1745100000 2025-04-19 22:00:00  incomplete         NaN     Villarreal
# 1746309600 2025-05-03 22:00:00  incomplete         NaN     Villarreal
# 1747173600 2025-05-13 22:00:00  incomplete         NaN     Villarreal
# 1748124000 2025-05-24 22:00:00  incomplete         NaN     Villarreal
#
#                   away_team_name                         referee  Game Week  \
# timestamp
# 1692466200           Real Madrid     José María Sánchez Martínez          2
# 1693598400         Celta de Vigo    Ricardo De Burgos Bengoetxea          4
# 1695495600           Valencia CF           Mateo Busquets Ferrer          6
# 1696161600            Granada CF          Pablo González Fuertes          8
# 1698494400         UD Las Palmas  Francisco José Hernández Maeso         11
# ...                          ...                             ...        ...
# 1743890400  Athletic Club Bilbao                             NaN         30
# 1745100000         Real Sociedad                             NaN         32
# 1746309600            CA Osasuna                             NaN         34
# 1747173600               Leganés                             NaN         36
# 1748124000            Sevilla FC                             NaN         38
#
#             Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_ppg  ...  Result  \
# timestamp                                                         ...
# 1692466200                  0.00                   3.0      0.58  ...       L
# 1693598400                  0.00                   1.0      0.58  ...       L
# 1695495600                  0.00                   1.5      0.58  ...       D
# 1696161600                  0.25                   0.0      0.58  ...       D
# 1698494400                  0.40                   0.6      0.58  ...       L
# ...                          ...                   ...       ...  ...     ...
# 1743890400                  1.00                   0.0      1.00  ...       D
# 1745100000                  1.00                   0.0      1.00  ...       D
# 1746309600                  1.00                   0.0      1.00  ...       D
# 1747173600                  1.00                   1.0      1.00  ...       D
# 1748124000                  1.00                   1.0      1.00  ...       D
#
#             time  home_team_code  away_team_code  stadium_code  day_of_week  \
# timestamp
# 1692466200    17               0              19            31            5
# 1693598400    20               0               6            31            4
# 1695495600    19               0              26            31            5
# 1696161600    12               0              12            31            6
# 1698494400    12               0              25            31            5
# ...          ...             ...             ...           ...          ...
# 1743890400    22              27               1            27            5
# 1745100000    22              27              20            27            5
# 1746309600    22              27               4            27            5
# 1747173600    22              27              13            27            1
# 1748124000    22              27              24            27            5
#
#             target home_team_goal_count_rolling home_team_shots_rolling  \
# timestamp
# 1692466200       0                         1.45                   13.25
# 1693598400       0                         1.45                   13.55
# 1695495600       2                         1.45                   13.55
# 1696161600       2                         1.55                   13.95
# 1698494400       0                         1.55                   14.25
# ...            ...                          ...                     ...
# 1743890400       2                         0.95                    4.30
# 1745100000       2                         0.70                    3.55
# 1746309600       2                         0.65                    2.85
# 1747173600       2                         0.60                    2.20
# 1748124000       2                         0.45                    1.60
#
#             home_team_shots_on_target_rolling
# timestamp
# 1692466200                               5.30
# 1693598400                               5.40
# 1695495600                               5.40
# 1696161600                               5.80
# 1698494400                               5.95
# ...                                       ...
# 1743890400                               1.85
# 1745100000                               1.25
# 1746309600                               0.80
# 1747173600                               0.60
# 1748124000                               0.15
#
# [1722 rows x 59 columns]

# %%
df_rolling.index = range(df_rolling.shape[0])
#df_rolling

# %%
from sklearn.metrics import precision_score

def future(data, predictor):
    train = data[data["date_GMT"] < '2024-04-01']
    test = data[data["date_GMT"] > '2024-04-01']
    rf.fit(train[predictor], train["target"])
    preds = rf.predict(test[predictor])
    combined = pd.DataFrame(dict(actual = test["target"], predictor = preds), index = test.index)
    precision = precision_score(test["target"], preds, average='weighted')

    return  precision, combined

# %%
precision, combined = future(df_rolling, predictor + new_cols) 
precision
# Out:
# np.float64(0.8316516482792844)

# %%
#combined

# %%
combined  = combined.merge(df_rolling[["date_GMT", "home_team_name", "away_team_name", "Result"]], left_index = True, right_index = True)
combined
# Out:
#       actual  predictor            date_GMT        home_team_name  \
# 14         0          2 2024-04-21 14:15:00               Almería
# 15         0          0 2024-04-27 14:15:00               Almería
# 16         0          2 2024-05-16 19:30:00               Almería
# 17         1          2 2024-05-25 16:30:00               Almería
# 89         2          1 2024-04-14 16:30:00  Athletic Club Bilbao
# ...      ...        ...                 ...                   ...
# 1717       2          2 2025-04-05 22:00:00            Villarreal
# 1718       2          2 2025-04-19 22:00:00            Villarreal
# 1719       2          2 2025-05-03 22:00:00            Villarreal
# 1720       2          2 2025-05-13 22:00:00            Villarreal
# 1721       2          2 2025-05-24 22:00:00            Villarreal
#
#             away_team_name Result
# 14              Villarreal      L
# 15               Getafe CF      L
# 16            FC Barcelona      L
# 17                   Cadiz      W
# 89              Villarreal      D
# ...                    ...    ...
# 1717  Athletic Club Bilbao      D
# 1718         Real Sociedad      D
# 1719            CA Osasuna      D
# 1720               Leganés      D
# 1721            Sevilla FC      D
#
# [456 rows x 6 columns]

# %%
def calculate_final_standings(combined):
    standings = {}


    result_mapping = {1: 'Win', 0: 'Loss', 2: 'Draw'}

    for index, row in combined.iterrows():
        home_team = row['home_team_name']
        away_team = row['away_team_name']
        result = row['actual'] 
        
        if home_team not in standings:
            standings[home_team] = 0
        if away_team not in standings:
            standings[away_team] = 0


        if result == 1:  # Home win
            standings[home_team] += 3
        elif result == 0:  # Away win
            standings[away_team] += 3
        elif result == 2:  # Draw
            standings[home_team] += 1
            standings[away_team] += 1



    standings_df = pd.DataFrame(list(standings.items()), columns=['Team', 'Points'])

    final_df = standings_df.sort_values(by='Points', ascending=False).reset_index(drop=True)




    print("\nFinal League Standings:")
    print(final_df)


calculate_final_standings(combined)
# Out:
# Final League Standings:
#                Team  Points
# 0   Atletico Madrid      59
# 1       Real Madrid      58
# 2      FC Barcelona      58
# 3        Villarreal      55
# 4     Celta de Vigo      55
# ..              ...     ...
# 18     RCD Espanyol      37
# 19    UD Las Palmas      37
# 20          Almería       8
# 21            Cadiz       8
# 22       Granada CF       7
#
# [23 rows x 2 columns]
